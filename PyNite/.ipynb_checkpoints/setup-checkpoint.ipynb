# %%
# !python setup.py build
# Out:
# running build
# running build_py
# copying PyNite/FEModel3D.py -> build/lib/PyNite
# running egg_info
# writing PyNiteFEA.egg-info/PKG-INFO
# writing dependency_links to PyNiteFEA.egg-info/dependency_links.txt
# writing requirements to PyNiteFEA.egg-info/requires.txt
# writing top-level names to PyNiteFEA.egg-info/top_level.txt
# reading manifest file 'PyNiteFEA.egg-info/SOURCES.txt'
# writing manifest file 'PyNiteFEA.egg-info/SOURCES.txt'

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing PyNiteFEA.egg-info/PKG-INFO
# writing dependency_links to PyNiteFEA.egg-info/dependency_links.txt
# writing requirements to PyNiteFEA.egg-info/requires.txt
# writing top-level names to PyNiteFEA.egg-info/top_level.txt
# reading manifest file 'PyNiteFEA.egg-info/SOURCES.txt'
# writing manifest file 'PyNiteFEA.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-10.9-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.macosx-10.9-x86_64/egg
# creating build/bdist.macosx-10.9-x86_64/egg/PyNite
# copying build/lib/PyNite/BeamSegZ.py -> build/bdist.macosx-10.9-x86_64/egg/PyNite
# copying build/lib/PyNite/LoadCombo.py -> build/bdist.macosx-10.9-x86_64/egg/PyNite
# copying build/lib/PyNite/MainStyleSheet.css -> build/bdist.macosx-10.9-x86_64/egg/PyNite
# copying build/lib/PyNite/Plate3D.py -> build/bdist.macosx-10.9-x86_64/egg/PyNite
# ...

# %%
# !pip install pdfkit
