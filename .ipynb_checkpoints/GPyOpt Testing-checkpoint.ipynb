# %%
from GPyOpt.methods import BayesianOptimization
import numpy as np
from numpy.random import randn
import time
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(24)

# %%
def one_dim(x):
    #1-D
    #optimum at x=0.96609, f(x)=-1.48907
    return -(1.4-3*x)*np.sin(18*x)+randn()*sigma
bounds_one_dim = [{'name':'x', 'type':'continuous', 'domain':(0, 1.2)}]

# %%
def booth(X):
    #2-D
    #optimum at X=[1,3] f(X)=0
    X = np.atleast_2d(X)
    x = X[:, 0]
    y = X[:, 1]
    return((x+2*y-7)**2+(2*x+y-5)**2)+randn()*sigma
bounds_booth = [{'name': 'x', 'type': 'continuous', 'domain': (-10,10)}]

# %%
def sphere(X):
    #n-D
    #optimum at X = [0,...,0], f(X)=0
    X = np.atleast_2d(X)
    return(np.sum(np.power(X,2), 1))+randn()*sigma
bounds_sphere = [{'name': 'x', 'type': 'continuous', 'domain': (-1,1)}]

# %%
def rastrigin(X):
    #n-D
    #optimum at X=[0,...,0], f(X)=0
    X = np.atleast_2d(X)
    return(10*len(X[0])+np.sum(np.power(X,2)-10*np.cos(2*np.pi*X),1))+randn()*sigma
bounds_rastrigin = [{'name': 'x', 'type': 'continuous', 'domain': (-5.12,5.12)}]

# %% [markdown]
# Hyperparameter testing done in gpyopt_test.py

# %%
# demonstrate with 1D - acquisition, noise effect, convergence
sigma=0
xdata = np.linspace(0, 1.2, 100)
ydata = [one_dim(x) for x in xdata]
plt.plot(xdata, ydata)
plt.show()
sigma = 0.1
myOpt = BayesianOptimization(one_dim, domain=bounds_one_dim, exact_feval=True, model="GP")
myOpt.run_optimization(max_iter=50, eps=1e-6)
myOpt.plot_acquisition()
myOpt.plot_convergence()
print(myOpt.x_opt, myOpt.fx_opt)
# Out:
# [0.9496045] -1.576189324252468

# %%
# show convergence for high dimension optimisation
sigma = 0
n=12
myOpt = BayesianOptimization(rastrigin, domain=bounds_rastrigin*n, exact_feval=True)
myOpt.run_optimization(max_iter=500, eps=1e-6)
myOpt.plot_convergence()
print(myOpt.x_opt, myOpt.fx_opt)
# Out:
# KeyboardInterrupt caught, calling on_optimization_end() to round things up
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-91ce8a5014ea> in <module>
#       3 n=12
#       4 myOpt = BayesianOptimization(rastrigin, domain=bounds_rastrigin*n, exact_feval=True)
# ----> 5 myOpt.run_optimization(max_iter=500, eps=1e-6)
#       6 myOpt.plot_convergence()
#       7 print(myOpt.x_opt, myOpt.fx_opt)
#
# /opt/anaconda3/lib/python3.8/site-packages/GPyOpt/core/bo.py in run_optimization(self, max_iter, max_time, eps, context, verbosity, save_models_parameters, report_file, evaluations_file, models_file)
#     135             # --- Update model
#     136             try:
# --> 137                 self._update_model(self.normalization_type)
#     138             except np.linalg.linalg.LinAlgError:
#     139                 break
#
# /opt/anaconda3/lib/python3.8/site-packages/GPyOpt/core/bo.py in _update_model(self, normalization_type)
#     251                 Y_inmodel = self.Y
#     252
# --> 253             self.model.updateModel(X_inmodel, Y_inmodel, None, None)
#     254
#     255         # Save parameters of the model
#
# /opt/anaconda3/lib/python3.8/site-packages/GPyOpt/models/gpmodel.py in updateModel(self, X_all, Y_all, X_new, Y_new)
#      91                 self.model.optimize(optimizer=self.optimizer, max_iters = self.max_iters, messages=False, ipython_notebook=False)
#      92             else:
# ---> 93                 self.model.optimize_restarts(num_restarts=self.optimize_restarts, optimizer=self.optimizer, max_iters = self.max_iters, verbose=self.verbose)
#      94
#      95     def _predict(self, X, full_cov, include_likelihood):
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/model.py in optimize_restarts(self, num_restarts, robust, verbose, parallel, num_processes, **kwargs)
#     170                     if i > 0:
#     171                         self.randomize()
# --> 172                     self.optimize(**kwargs)
#     173                 else:#pragma: no cover
#     174                     self.optimization_runs.append(jobs[i])
#
# /opt/anaconda3/lib/python3.8/site-packages/GPy/core/gp.py in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     657         self.inference_method.on_optimization_start()
#     658         try:
# --> 659             ret = super(GP, self).optimize(optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     660         except KeyboardInterrupt:
#     661             print("KeyboardInterrupt caught, calling on_optimization_end() to round things up")
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/model.py in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     109
#     110         with VerboseOptimization(self, opt, maxiters=max_iters, verbose=messages, ipython_notebook=ipython_notebook, clear_after_finish=clear_after_finish) as vo:
# --> 111             opt.run(start, f_fp=self._objective_grads, f=self._objective, fp=self._grads)
#     112
#     113         self.optimizer_array = opt.x_opt
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/optimization/optimization.py in run(self, x_init, **kwargs)
#      49     def run(self, x_init, **kwargs):
#      50         start = dt.datetime.now()
# ---> 51         self.opt(x_init, **kwargs)
#      52         end = dt.datetime.now()
#      53         self.time = str(end - start)
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/optimization/optimization.py in opt(self, x_init, f_fp, f, fp)
#     122             opt_dict['factr'] = self.bfgs_factor
#     123
# --> 124         opt_result = optimize.fmin_l_bfgs_b(f_fp, x_init, maxfun=self.max_iters, maxiter=self.max_iters, **opt_dict)
#     125         self.x_opt = opt_result[0]
#     126         self.f_opt = f_fp(self.x_opt)[0]
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/model.py in _objective_grads(self, x)
#     271     def _objective_grads(self, x):
#     272         try:
# --> 273             self.optimizer_array = x
#     274             obj_f, self.obj_grads = self.objective_function(), self._transform_gradients(self.objective_function_gradients())
#     275             self._fail_count = 0
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/parameterized.py in __setattr__(self, name, val)
#     337                 param = self.parameters[pnames.index(name)]
#     338                 param[:] = val; return
# --> 339         return object.__setattr__(self, name, val)
#     340
#     341     #===========================================================================
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/core/parameter_core.py in optimizer_array(self, p)
#     122
#     123         self._optimizer_copy_transformed = False
# --> 124         self.trigger_update()
#     125
#     126     def _trigger_params_changed(self, trigger_parent=True):
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/core/updateable.py in trigger_update(self, trigger_parent)
#      77             #print "Warning: updates are off, updating the model will do nothing"
#      78             return
# ---> 79         self._trigger_params_changed(trigger_parent)
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/core/parameter_core.py in _trigger_params_changed(self, trigger_parent)
#     132         """
#     133         [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
# --> 134         self.notify_observers(None, None if trigger_parent else -np.inf)
#     135
#     136     def _size_transformed(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/core/observable.py in notify_observers(self, which, min_priority)
#      89                 which = self
#      90             if min_priority is None:
# ---> 91                 [callble(self, which=which) for _, _, callble in self.observers]
#      92             else:
#      93                 for p, _, callble in self.observers:
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/core/observable.py in <listcomp>(.0)
#      89                 which = self
#      90             if min_priority is None:
# ---> 91                 [callble(self, which=which) for _, _, callble in self.observers]
#      92             else:
#      93                 for p, _, callble in self.observers:
#
# /opt/anaconda3/lib/python3.8/site-packages/paramz/core/parameter_core.py in _parameters_changed_notification(self, me, which)
#     506         """
#     507         self._optimizer_copy_transformed = False # tells the optimizer array to update on next request
# --> 508         self.parameters_changed()
#     509     def _pass_through_notify_observers(self, me, which=None):
#     510         self.notify_observers(which=which)
#
# /opt/anaconda3/lib/python3.8/site-packages/GPy/core/gp.py in parameters_changed(self)
#     265             this method yourself, there may be unexpected consequences.
#     266         """
# --> 267         self.posterior, self._log_marginal_likelihood, self.grad_dict = self.inference_method.inference(self.kern, self.X, self.likelihood, self.Y_normalized, self.mean_function, self.Y_metadata)
#     268         self.likelihood.update_gradients(self.grad_dict['dL_dthetaL'])
#     269         self.kern.update_gradients_full(self.grad_dict['dL_dK'], self.X)
#
# /opt/anaconda3/lib/python3.8/site-packages/GPy/inference/latent_function_inference/exact_gaussian_inference.py in inference(self, kern, X, likelihood, Y, mean_function, Y_metadata, K, variance, Z_tilde)
#      56         diag.add(Ky, variance+1e-8)
#      57
# ---> 58         Wi, LW, LWi, W_logdet = pdinv(Ky)
#      59
#      60         alpha, _ = dpotrs(LW, YYT_factor, lower=1)
#
# /opt/anaconda3/lib/python3.8/site-packages/GPy/util/linalg.py in pdinv(A, *args)
#     205
#     206     """
# --> 207     L = jitchol(A, *args)
#     208     logdet = 2.*np.sum(np.log(np.diag(L)))
#     209     Li = dtrtri(L)
#
# /opt/anaconda3/lib/python3.8/site-packages/GPy/util/linalg.py in jitchol(A, maxtries)
#      56 def jitchol(A, maxtries=5):
#      57     A = np.ascontiguousarray(A)
# ---> 58     L, info = lapack.dpotrf(A, lower=1)
#      59     if info == 0:
#      60         return L
#
# KeyboardInterrupt:

# %%
# get optimisation timing as number of iterations increases
results = pd.DataFrame(None)

n = 10
sigma = 0
max_time = 600
actual_x = [[0]*n]
actual_f = 0
acq_type = "LCB"

for seed in [1,2,3,4,5]:
    np.random.seed(seed)
    for function in [sphere, rastrigin]:
        if function == sphere:
            domain = bounds_sphere*n
            func_name = "sphere"
        else:
            domain = bounds_rastrigin*n
            func_name = "rastrigin"
        
        for max_iter in [50, 70, 90, 110, 130, 150]:
            myOpt = BayesianOptimization(function,
                                        domain=domain,
                                        acquisition_type=acq_type,
                                        exact_feval=True)
            myOpt.run_optimization(max_iter = max_iter, max_time = max_time, eps=1e-6)
            
            result = {"n": n,"function":func_name, "sigma": sigma, "max_it": max_iter, "max_time": max_time, "acquisition func": acq_type, 
                    "eucl_dist to true x_opt": float(np.linalg.norm(myOpt.x_opt-actual_x)), 
                    "diff to true f(x_opt)": float(np.abs(function(myOpt.x_opt)-actual_f)), "actual_it": myOpt.num_acquisitions,
                    "actual_time": myOpt.cum_time}
    
            results = results.append(result, ignore_index=True)
            print(myOpt.x_opt, result)
# Out:
# [-0.39533485 -0.20646505  0.75623487 -0.71922612  0.38464523 -0.66033916
#   0.06633057 -0.96342345  0.57855866 -0.42444932] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.8219677415920152, 'diff to true f(x_opt)': 3.3195664514019088, 'actual_it': 1, 'actual_time': 0.30343174934387207}
# [-0.21636743  0.52176535  0.5933427   0.72808043  0.61596974  0.05106556
#   0.37123325 -0.17435624  0.39556215 -0.4356465 ] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.4483468296979705, 'diff to true f(x_opt)': 2.0977085390961614, 'actual_it': 1, 'actual_time': 0.18376684188842773}
# [-0.03404321 -0.22855892 -0.44983443  0.49531554 -0.9162588  -0.18452467
#   0.12576366 -0.29108286 -0.51999216  0.92460673] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.6126070022288743, 'diff to true f(x_opt)': 2.600501343637597, 'actual_it': 1, 'actual_time': 0.28111791610717773}
# [-0.30484183  0.26531137  0.36496205 -0.41182707 -0.65554523  0.17995242
#  -0.50674023  0.39800049  0.76969755 -0.77319326] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.
{'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 0.8870422443752656, 'diff to true f(x_opt)': 0.7868439433063081, 'actual_it': 1, 'actual_time': 0.18495416641235352}
# [ 0.28798375 -0.61383582 -0.02460323 -0.43701731 -0.5340192   0.49618713
#  -0.84838569 -0.52121454  0.02079309 -0.23419739] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.4931176466203013, 'diff to true f(x_opt)': 2.2294003066489463, 'actual_it': 1, 'actual_time': 0.18485522270202637}
# [ 3.07905082 -3.6950843   0.14483884  0.16618204 -4.27531811 -3.95466554
#   3.03978704 -0.15980952  0.40720041  2.05712933] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 8.412131640212854, 'diff to true f(x_opt)': 130.10588338543602, 'actual_it': 1, 'actual_time': 0.06105399131774902}
# [-4.10468806 -1.77414564 -2.09293522 -2.72560633  0.77988492 -3.64382557
#  -2.42682584 -1.00940638 -2.44104791 -0.76650614] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 7.690622941658569, 'diff to true f(x_opt)': 154.4905761704601, 'actual_it': 1, 'actual_time': 0.16769886016845703}
# [-3.06507074  3.00898006 -0.62442664  2.81961623  1.83295569 -0.67337926
#  -0.66352822  1.15975579 -0.666975   -1.76384605] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 5.995268287882044, 'diff to true f(x_opt)': 123.20778672061374, 'actual_it': 1, 'actual_time': 0.27570199966430664}
# [ 0.22192044 -1.35157617  3.86121809  0.93040563  3.27202226  3.68145199
#  -2.12179606 -3.88966286 -3.18416307  0.70746174] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 8.495927100178646, 'diff to true f(x_opt)': 150.16332779598272, 'actual_it': 1, 'actual_time': 0.11341738700866699}
# [ 4.37296181  3.15876146  0.46279973  0.33407164 -3.70159677 -2.36576088
#   0.02612833  3.22591503 -2.08771802 -1.84141567] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 8.178116423288484, 'diff to true f(x_opt)': 167.5239426025922, 'actual_it': 1, 'actual_time': 0.18973088264465332}
# [-1.06758498 -0.83745318 -0.07749816  1.36021599  0.1313455  -3.90914119
#   1.50003204 -0.11060624 -1.13483792  2.30566478] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 5.278463087129759, 'diff to true f(x_opt)': 95.00209766840766, 'actual_it': 1, 'actual_time': 0.08107376098632812}
# [ 0.93405968 -0.56782101  0.55876584  0.19466789 -0.12770671 -0.85010283
#   0.05581765  0.0904053  -0.20619999  0.00506612] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.5289930294205052, 'diff to true f(x_opt)': 2.3378196840164933, 'actual_it': 1, 'actual_time': 0.12426304817199707}
# [-0.040646    0.06515776  0.59845872 -0.32571044  0.82509995  0.01804254
#   0.36450383  0.06346825 -0.66917341 -0.90130511] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.5963359414436595, 'diff to true f(x_opt)': 2.548288437944815, 'actual_it': 1, 'actual_time': 0.3204967975616455}
# [ 0.04901679 -0.93284465  0.27694116 -0.19450172 -0.27322638  0.06540328
#   0.50979332  0.37076172  0.52224837 -0.54183376] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.4246894429117294, 'diff to true f(x_opt)': 2.0297400087441333, 'actual_it': 1, 'actual_time': 0.36565399169921875}
# [-0.77515592  0.10732208 -0.53278752  0.36176528 -0.2618196   0.18191204
#  -0.13259318  0.75646874  0.06972835 -0.45801958] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.3904074086896239, 'diff to true f(x_opt)': 1.9332327621389944, 'actual_it': 1, 'actual_time': 0.21213889122009277}
# [-0.15872676  0.24824321  0.03746809 -0.78686348  0.12817127 -0.39533739
#   0.30737687  0.13785491  0.86516531  0.08971961] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.322929146288326, 'diff to true f(x_opt)': 1.7501415260991593, 'actual_it': 1, 'actual_time': 0.19515490531921387}
# [ 0.16025709  0.35791939 -0.44624356  0.70085737  0.88132289  0.52218433
#  -0.58657975 -0.43501538  0.03433701 -0.18838734] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.569558058978752, 'diff to true f(x_opt)': 2.4635125005051473, 'actual_it': 1, 'actual_time': 0.22640156745910645}
# [-0.74363089  2.14026523 -0.96484893  1.03028584  4.20411134  2.30799229
#  -2.63824183 -5.11824337  1.01581833 -4.66972846] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 9.280221492104387, 'diff to true f(x_opt)': 155.2807949528447, 'actual_it': 1, 'actual_time': 0.1886758804321289}
# [ 0.75615312  0.31926747 -1.0544969   3.15399811  1.13482559  0.30141928
#   4.3553356  -0.17623007  0.90120785 -0.14102713] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 5.7396967874174, 'diff to true f(x_opt)': 105.45085919855289, 'actual_it': 1, 'actual_time': 0.07161498069763184}
# [-0.89562668 -2.02144345 -0.23307591 -5.04127436 -1.39109102 -2.96206115
#   1.71963222 -1.68842852 -3.10314715  3.19580832] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 8.168031078212598, 'diff to true f(x_opt)': 130.54364172508485, 'actual_it': 1, 'actual_time': 0.057538747787475586}
# [-1.91676482 -3.73738636 -1.50390809 -2.09486443 -2.60521553  3.86768905
#   1.95534284  0.20905306 -4.80828608 -1.34240611] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 8.650268506623195, 'diff to true f(x_opt)': 159.58223043184833, 'actual_it': 1, 'actual_time': 0.10570025444030762}
# [-2.67397141 -0.46126586  2.86422043  3.42900022 -3.05742974  0.34398032
#  -0.87493194  1.10878319 -1.97026012 -3.40683784] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 7.367106936343824, 'diff to true f(x_opt)': 150.92129418273132, 'actual_it': 1, 'actual_time': 0.26670289039611816}
# [-0.87831688  1.95256879  4.31173998 -3.27841603 -1.083405    3.2038779
#  -1.53259251  1.08252245 -1.13574208 -3.8821418 ] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 8.077332998019205, 'diff to true f(x_opt)': 129.65652125856352, 'actual_it': 1, 'actual_time': 0.07281184196472168}
# [-0.58656169  0.03683598 -0.11738155 -0.40784013 -0.43062824  0.92786106
#   0.39968723  0.03094522  0.74096617 -0.20211039] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.5239676181707595, 'diff to true f(x_opt)': 2.322477301233058, 'actual_it': 1, 'actual_time': 0.23677301406860352}
# [-0.03269057 -0.07159623  0.59470063  0.72499915  0.07338319 -0.79918697
#   0.5723124   0.21282041 -0.4739717   0.50300565] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.5427475733091254, 'diff to true f(x_opt)': 2.380070074951195, 'actual_it': 1, 'actual_time': 0.3742079734802246}
# [ 0.36566735  0.82229684  0.43908141 -0.11549337  0.13945659  0.20874994
#   0.366576   -0.52891021  0.02158115 -0.07622584] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.224516508366313, 'diff to true f(x_opt)': 1.4994406792616266, 'actual_it': 1, 'actual_time': 0.42212605476379395}
# [-0.58777628 -0.37475454  0.33832225 -0.49520776 -0.19033307 -0.96687504
#   0.02641159 -0.72509377  0.61884931 -0.23090481] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.6671648547576103, 'diff to true f(x_opt)': 2.779438652938964, 'actual_it': 1, 'actual_time': 0.18610620498657227}
# [-0.09167107 -0.35113966  0.90678982  0.46930512 -0.17096817  0.56449732
#   0.44549392 -0.25433133 -0.3738653  -0.46678032] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.463869341216061, 'diff to true f(x_opt)': 2.1429134481523446, 'actual_it': 1, 'actual_time': 0.1408679485321045}
# [ 0.60962307  0.53342052  0.44336739  0.10253052  0.83739047  0.6837665
#  -0.64282693  0.15394538  0.11290278  0.50460944] {'n': 10, 'function': 'sphere', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 1.6541848928265537, 'diff to true f(x_opt)': 2.7363276596555965, 'actual_it': 1, 'actual_time': 0.20924615859985352}
# [-0.78535943 -4.22445508 -0.90647304  3.88344501 -0.10336215  1.56177963
#  -1.72449147 -4.53675304 -2.62549524  2.63997361] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 8.615925541610931, 'diff to true f(x_opt)': 180.72074820454932, 'actual_it': 1, 'actual_time': 0.07152056694030762}
# [ 1.94247625  4.90051477 -1.04913208 -4.20100692  0.26146293  3.05719559
#  -2.89071325  4.51238098 -2.62073264 -4.01754078] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 10.376843576576517, 'diff to true f(x_opt)': 168.57195394517296, 'actual_it': 1, 'actual_time': 0.24817991256713867}
# [ 4.98028009  3.5357291  -2.11540313  1.95749518 -3.07843556  0.9092894
#   1.81446875 -0.51666884  1.87475815 -2.05275224] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 8.197720047341988, 'diff to true f(x_opt)': 122.15760852957517, 'actual_it': 1, 'actual_time': 0.1776590347290039}
# [-1.12200508 -0.05567711 -3.51016343  3.27977205 -1.18280751 -3.21808931
#  -2.30980874 -1.38723441  1.80116959 -2.04810642] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 7.126981640008875, 'diff to true f(x_opt)': 138.50356714162166, 'actual_it': 1, 'actual_time': 0.07391595840454102}
# [ 0.2162374   0.67343281  0.06333387  3.46023231  1.07922961 -0.12611702
#  -0.28303687 -4.92814127 -1.46089776  5.11996866] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 8.146969915317685, 'diff to true f(x_opt)': 149.0299658668372, 'actual_it': 1, 'actual_time': 0.16658592224121094}
# [-1.5681836   5.07495541 -0.1035738  -1.82980404  3.69044438  3.0708046
#  -3.08165972  3.2414794   2.09534188 -3.08003673] {'n': 10, 'function': 'rastrigin', 'sigma': 0, 'max_it': 20, 'max_time': 600, 'acquisition func': 'LCB', 'eucl_dist to true x_opt': 9.407624692084863, 'diff to true f(x_opt)': 144.28595170345073, 'actual_it': 1, 'actual_time': 0.07011294364929199}

# %%
results.to_excel("gpyopt_temp_results.xlsx", index=False)

# %% [markdown]
# Sparse GP tested in gpyopt_test.py

# %%
# difference between using GP and sparseGP
sigma=0
xdata = np.linspace(0, 1.2, 100)
ydata = [one_dim(x) for x in xdata]
plt.plot(xdata, ydata)
plt.show()
sigma = 0.1
myOpt = BayesianOptimization(one_dim, domain=bounds_one_dim, exact_feval=True, model_type="GP")
myOpt.run_optimization(max_iter=100, eps=1e-6)
myOpt.plot_acquisition()
myOpt.plot_convergence()
print(myOpt.cum_time)
myOpt = BayesianOptimization(one_dim, domain=bounds_one_dim, exact_feval=True, model_type="sparseGP")
myOpt.run_optimization(max_iter=100, eps=1e-6)
myOpt.plot_acquisition()
myOpt.plot_convergence()
print(myOpt.cum_time)
# Out:
# 22.795727968215942
# 94.86411619186401

# %%
sigma = 0.1
x_samples = np.random.rand(10000,2)*20-10
y_samples = np.array([booth(X) for X in x_samples])

myOpt = BayesianOptimization(booth, domain=bounds_booth*2, X=x_samples, Y=y_samples, exact_feval=True, model_type="sparseGP")
tic = time.perf_counter()
myOpt.run_optimization()
toc = time.perf_counter()
print(toc-tic)
print(myOpt.x_opt)

myOpt = BayesianOptimization(booth, domain=bounds_booth*2, X=x_samples, Y=y_samples, exact_feval=True, model_type="GP")
tic = time.perf_counter()
myOpt.run_optimization()
toc = time.perf_counter()
print(toc-tic)
print(myOpt.x_opt)
# Out:
# 2866.153956858001
# [1.28324226 2.7801364 ]
